# %% [markdown]
# **Target Variable(s): Executive Function Scores**
#
# 1. Interference
# 2. Working Memory
# 3. Cognitive Flexibility

# %% [markdown]
# # Data Import + Wrangling

# %%
import pandas as pd

# %%
data = pd.ExcelFile('/Users/springboard/Desktop/Capstone-Project/Obesity.xlsx')

df = data.parse('Full sample_EF_excel')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 513 entries, 0 to 512
# Data columns (total 25 columns):
# Reference_no              513 non-null int64
# Actual_age_C              513 non-null float64
# Sex                       513 non-null int64
# Weight                    513 non-null float64
# Height_meter              513 non-null float64
# BMI                       513 non-null float64
# BMI_for_age               513 non-null float64
# Physical_fitness_score    513 non-null float64
# PFS_CAT                   513 non-null int64
# Breakfast                 513 non-null int64
# Lunch                     513 non-null int64
# Dinner                    513 non-null int64
# PA_total_score            513 non-null float64
# PA_CAT                    513 non-null int64
# Sleep_weekdays            513 non-null float64
# Sleep_weekend             513 non-null float64
# Sleep_percent             513 non-null float64
# Global_sleep_CAT          513 non-null int64
# Household_size            486 non-null float64
# Income_CAT                486 non-null float64
# Edu_father                486 non-null float64
# Edu_mother                486 non-null float64
# Interference_score_ALL    513 non-null float64
# WM_total                  513 non-null int64
# CF_total                  513 non-null float64
# dtypes: float64(16), int64(9)
# memory usage: 104.2 KB

# %%
df.head()
# Out:
#    Reference_no  Actual_age_C  Sex  Weight  Height_meter        BMI  \
# 0             1     12.106776    2    30.6         1.420  15.175560
# 1             2     12.114990    1    33.4         1.492  15.004061
# 2             3     12.125941    1    66.8         1.518  28.988979
# 3             4     12.139630    1    40.4         1.466  18.798077
# 4             5     12.167009    2    40.1         1.475  18.431485
#
#    BMI_for_age  Physical_fitness_score  PFS_CAT  Breakfast    ...     \
# 0        -1.51               54.545455        1          7    ...
# 1        -1.60               62.500000        2          7    ...
# 2         2.86               55.045872        2          6    ...
# 3         0.53               56.206089        2          7    ...
# 4         0.12               63.829787        2          7    ...
#
#    Sleep_weekend  Sleep_percent  Global_sleep_CAT  Household_size  Income_CAT  \
# 0           7.25      95.238095                 1               6           2
# 1          11.50      95.652174                 0               4           3
# 2           8.00      91.428571                 1               3           1
# 3          11.00      76.190476                 1               4           1
# 4          11.25      98.876404                 0               3           1
#
#    Edu_father  Edu_mother  Interference_score_ALL  WM_total  CF_total
# 0           3           3               10.409091        16     18.00
# 1           4           3               -2.697183        16     27.00
# 2           3           2                6.598361        16      4.31
# 3           3           4                1.454545        15     45.16
# 4           2           3                0.291339        15     15.07
#
# [5 rows x 25 columns]

# %%
# Drop duplicate data (if any)

df.drop_duplicates()
# Out:
#      Reference_no  Actual_age_C  Sex  Weight  Height_meter        BMI  \
# 0               1     12.106776    2    30.6        1.4200  15.175560
# 1               2     12.114990    1    33.4        1.4920  15.004061
# 2               3     12.125941    1    66.8        1.5180  28.988979
# 3               4     12.139630    1    40.4        1.4660  18.798077
# 4               5     12.167009    2    40.1        1.4750  18.431485
# 5               6     12.180698    1    53.5        1.6600  19.415009
# 6               7     12.183436    1    31.4        1.4650  14.630339
# 7               8     12.197125    1    61.4        1.5640  25.101223
# 8               9     12.213552    2    46.4        1.5300  19.821436
# 9              10     12.213552    2    27.0        1.3990  13.795211
# 10             11     12.238193    2    36.4        1.5055  16.059790
# 11             12     12.240931    1    57.2        1.4670  26.578826
# 12             13     12.246407    1    44.6        1.4470  21.300892
# 13             14     12.265572    1    34.6        1.3930  17.830925
# 14             15     12.268309    1    27.8        1.3890  14.409214
# 15             16     12.268309    2    39.2        1.4890  17.680587
# 16             17     12.276523    2    60.4        1.6050  23.446977
# 17             18     12.290212    1    39.6        1.4880  17.885016
# 18             19     12.303901    2    35.0        1.5115  15.319752
# 19             20     12.306639    2    51.8        1.5655  21.136040
# 20             21     12.323066    1    58.2        1.4920  26.144801
# 21             22     12.325804    1    54.4        1.5580  22.411142
# 22             23     12.339493    1    49.6        1.4700  22.953399
# 23             24     12.350445    1    41.6        1.4785  19.030521
# 24             25     12.355921    1    41.8        1.3940  21.510511
# 25             26     12.369610    1    52.0        1.5095  22.821128
# 26             27     12.372348    2    45.6        1.4970  20.347977
# 27             28     12.388775    2    32.7        1.5250  14.060736
# 28             29     12.388775    2    50.3        1.4560  23.727131
# 29             30     12.391513    1    56.4        1.5630  23.086662
# ..            ...           ...  ...     ...           ...        ...
# 483           484     16.019165    2    44.8        1.5600  18.408941
# 484           485     16.024641    2    63.8        1.5490  26.589970
# 485           486     16.030116    1    89.6        1.7540  29.123853
# 486           487     16.035592    2    54.8        1.5690  22.260488
# 487           488     16.043806    1    61.0        1.6890  21.383094
# 488           489     16.052019    2    49.4        1.4720  22.798765
# 489           490     16.057495    2    60.0        1.5205  25.952452
# 490           491     16.068446    2    62.8        1.6940  21.884309
# 491           492     16.076660    2    66.2        1.5510  27.519111
# 492           493     16.076660    2    46.2        1.6350  17.282496
# 493           494     16.076660    1    48.8        1.6080  18.873295
# 494           495     16.079398    2    47.8        1.5130  20.880940
# 495           496     16.087611    2    55.8        1.5270  23.930740
# 496           497     16.093087    2    68.0        1.6040  26.430184
# 497           498     16.095825    1    84.8        1.6900  29.690837
# 498           499     16.106776    2    73.4        1.5830  29.291002
# 499           500     16.131417    2    46.0        1.5940  18.104277
# 500           501     16.142368    1    51.6        1.7000  17.854671
# 501           502     16.243669    2    74.2        1.5650  30.295297
# 502           503     16.284736    2    44.8        1.5840  17.855321
# 503           504     16.396988    1    56.8        1.6900  19.887259
# 504           505     16.429843    1    60.2        1.6260  22.769600
# 505           506     16.511978    2    88.3        1.6605  32.024543
# 506           507     16.618754    2    49.7        1.5890  19.683784
# 507           508     16.624230    2    45.4        1.6140  17.428050
# 508           509     16.629706    1    52.0        1.6510  19.076961
# 509           510     16.783025    1    57.4        1.7215  19.368583
# 510           511     16.826831    1    57.0        1.6510  20.911284
# 511           512     16.906229    2    53.2        1.5000  23.644444
# 512           513     16.970000    2    40.2        1.7110  13.731755
#
#      BMI_for_age  Physical_fitness_score  PFS_CAT  Breakfast    ...     \
# 0          -1.51               54.545455        1          7    ...
# 1          -1.60               62.500000        2          7    ...
# 2           2.86               55.045872        2          6    ...
# 3           0.53               56.206089        2          7    ...
# 4           0.12               63.829787        2          7    ...
# 5           0.76               56.074766        2          2    ...
# 6          -1.92               79.207921        3          5    ...
# 7           2.26               73.394495        3          5    ...
# 8           0.62               66.666667        3          0    ...
# 9          -2.54               58.394161        2          7    ...
# 10         -1.03               49.896050        1          2    ...
# 11          2.50               52.631579        1          3    ...
# 12          1.36               52.516411        1          7    ...
# 13          0.06               66.115702        3          6    ...
# 14         -2.14               71.428571        3          5    ...
# 15         -0.23               75.471698        3          7    ...
# 16          1.61               34.246575        1          2    ...
# 17          0.08               76.190476        3          3    ...
# 18         -1.49               54.669704        1          6    ...
# 19          1.01               57.831325        2          3    ...
# 20          2.41               65.040650        3          2    ...
# 21          1.64               79.734219        3          7    ...
# 22          1.77               56.872038        2          3    ...
# 23          0.55               76.433121        3          7    ...
# 24          1.39               65.040650        3          3    ...
# 25          1.73               63.157895        2          2    ...
# 26          0.75               59.113300        2          7    ...
# 27         -2.40               64.343164        2          3    ...
# 28          1.65               58.679707        2          2    ...
# 29          1.79               59.259259        2          7    ...
# ..           ...                     ...      ...        ...    ...
# 483        -0.89               60.453401        2          4    ...
# 484         1.56               60.301508        2          3    ...
# 485         2.22               61.855670        2          5    ...
# 486         0.49               66.481994        3          7    ...
# 487         0.32               80.267559        4          2    ...
# 488         0.65               62.176166        2          5    ...
# 489         1.43               60.606061        2          7    ...
# 490         0.37               53.811659        1          7    ...
# 491         1.74               57.553957        2          4    ...
# 492        -1.42               70.588235        3          7    ...
# 493        -0.72               77.419355        3          7    ...
# 494         0.05               56.603774        2          5    ...
# 495         0.95               59.113300        2          4    ...
# 496         1.52              102.564103        5          3    ...
# 497         2.30               65.934066        3          5    ...
# 498         2.06               54.054054        1          0    ...
# 499        -1.04               28.846154        1          5    ...
# 500        -1.22               80.808081        4          4    ...
# 501         2.22               56.074766        2          5    ...
# 502        -1.17               64.171123        2          3    ...
# 503        -0.35               66.298343        3          5    ...
# 504         0.92               62.176166        2          2    ...
# 505         2.46               65.573770        3          7    ...
# 506        -0.45               61.381074        2          2    ...
# 507        -1.41               55.944056        2          3    ...
# 508        -0.77               78.431373        3          7    ...
# 509        -0.67               59.850374        2          2    ...
# 510        -0.05               77.669903        3          3    ...
# 511         0.89               62.015504        2          7    ...
# 512        -2.49               55.214724        2          3    ...
#
#      Sleep_weekend  Sleep_percent  Global_sleep_CAT  Household_size  \
# 0             7.25      95.238095                 1               6
# 1            11.50      95.652174                 0               4
# 2             8.00      91.428571                 1               3
# 3            11.00      76.190476                 1               4
# 4            11.25      98.876404                 0               3
# 5            12.00      70.000000                 1               4
# 6             9.50      95.238095                 0               7
# 7             6.00     100.000000                 1               6
# 8            10.00      70.422535                 1               6
# 9             8.00     100.000000                 1               5
# 10            9.00      94.117647                 1               4
# 11            4.00     100.000000                 1               5
# 12            8.00     100.000000                 1               4
# 13            9.00      97.297297                 0               5
# 14            9.00      75.675676                 1               7
# 15            9.00     100.000000                 0               4
# 16            9.25      91.139241                 0               7
# 17           13.00      53.333333                 1               5
# 18            9.50      75.000000                 1               6
# 19           10.00     100.000000                 0               4
# 20            7.00     100.000000                 1               5
# 21            7.50     100.000000                 1              10
# 22           12.00      74.418605                 1              10
# 23            8.00      96.277279                 0               4
# 24            7.00     100.000000                 0               6
# 25           10.00      80.000000                 1               4
# 26           10.00      88.888889                 1               5
# 27            9.33      67.385445                 1               6
# 28            9.00      70.588235                 1               3
# 29           12.00      72.727273                 1               7
# ..             ...            ...               ...             ...
# 483           6.50      97.879282                 1               5
# 484           8.00      98.176718                 1               6
# 485          10.00      97.297297                 0               4
# 486           4.50     100.000000                 1               3
# 487           3.50      95.652174                 1               9
# 488           8.00      88.421053                 1               6
# 489          12.50      70.000000                 1               7
# 490          10.00      60.000000                 1               5
# 491           9.00      38.709677                 1               3
# 492           8.50      94.193548                 0               6
# 493           8.00      96.000000                 1              10
# 494           7.25     101.818182                 0              12
# 495          10.00      77.777778                 1               7
# 496          11.00      80.000000                 1               4
# 497           8.00      92.307692                 0               6
# 498           8.00      80.898876                 1               5
# 499          10.17      74.226804                 1               6
# 500           8.00      51.612903                 1               4
# 501          11.00      95.948827                 0               5
# 502           9.00      86.896552                 0               9
# 503           9.50      96.296296                 1             NaN
# 504           7.00      80.000000                 1               5
# 505           9.00      85.714286                 1               5
# 506          10.50      85.287846                 1               5
# 507          10.00      93.333333                 1               7
# 508           8.00      90.909091                 0               4
# 509          11.00      31.578947                 1               9
# 510           9.00      61.538462                 1             NaN
# 511           9.00     100.000000                 0               6
# 512           7.50      87.209302                 1               6
#
#      Income_CAT  Edu_father  Edu_mother  Interference_score_ALL  WM_total  \
# 0             2           3           3               10.409091        16
# 1             3           4           3               -2.697183        16
# 2             1           3           2                6.598361        16
# 3             1           3           4                1.454545        15
# 4             1           2           3                0.291339        15
# 5             3           4           4                2.657534        17
# 6             1           3           3                5.225806        26
# 7             3           4           4                0.939394        13
# 8             3           4           4               -7.417178        16
# 9             2           3           3               -3.853659        17
# 10            3           4           4                3.058824        21
# 11            2           4           3               10.752212        17
# 12            2           4           3                2.376812        19
# 13            1           2           2               -0.285714        18
# 14            2           3           4                3.495868        15
# 15            1           4           4                2.654412        19
# 16            2           3           4                1.836735        12
# 17            2           3           3                8.000000        12
# 18            3           3           3                0.500000        16
# 19            2           3           3                2.219101        25
# 20            3           3           4               -2.189189        13
# 21            3           4           4               -6.343284        12
# 22            1           3           3                0.963768        15
# 23            2           4           4                9.560000        22
# 24            1           3           3               -4.014388        18
# 25            3           4           4                1.376623        16
# 26            3           4           4                6.801527        14
# 27            1           4           4               -9.617647        19
# 28            1           3           3               -8.172414        12
# 29            2           4           4               -7.935484        17
# ..          ...         ...         ...                     ...       ...
# 483           1           3           3                0.222222        16
# 484           1           3           3               -2.372414        15
# 485           2           3           3               -1.759036        22
# 486           2           3           4                3.975610        15
# 487           1           3           3                3.167630        18
# 488           2           3           3               -5.655914        17
# 489           1           3           2                1.942197        20
# 490           2           3           3               -2.653543        15
# 491           1           3           3              -11.116279        10
# 492           2           3           3                5.689655        20
# 493           1           3           2               12.173611        19
# 494           2           2           3               -7.670886        20
# 495           2           3           3                3.000000        16
# 496           1           3           3                5.564103        16
# 497           3           3           3               -7.302326        18
# 498           1           3           3               -3.290323        15
# 499           2           4           3              -19.459716        18
# 500           1           3           3                1.943396        11
# 501           2           3           3               -1.223077        15
# 502           1           3           3               -1.878788        15
# 503         NaN         NaN         NaN               -1.228758        14
# 504           1           3           3                1.000000        16
# 505           2           2           3               -0.468750        29
# 506           1           3           3                7.306667        20
# 507           1           3           3                5.214286        20
# 508           1           3           3               -0.333333        25
# 509           1           2           3               -5.154930        19
# 510         NaN         NaN         NaN                2.600000        18
# 511           1           3           3                1.469231        16
# 512           2           3           2                9.479532        17
#
#      CF_total
# 0       18.00
# 1       27.00
# 2        4.31
# 3       45.16
# 4       15.07
# 5       24.40
# 6       33.00
# 7       33.96
# 8       15.70
# 9       36.99
# 10      44.00
# 11      18.60
# 12      31.00
# 13      23.00
# 14      51.00
# 15      14.24
# 16      19.00
# 17      75.71
# 18      30.77
# 19      41.56
# 20       5.10
# 21     136.62
# 22      58.00
# 23      -1.00
# 24      53.55
# 25       9.83
# 26      47.60
# 27      72.50
# 28       9.60
# 29      72.00
# ..        ...
# 483     13.03
# 484     41.00
# 485     27.00
# 486     15.24
# 487     10.53
# 488     41.00
# 489     17.67
# 490     62.40
# 491     67.00
# 492     14.91
# 493     11.00
# 494     18.00
# 495     11.00
# 496     19.80
# 497     56.17
# 498      7.88
# 499     19.00
# 500     37.00
# 501      4.60
# 502      8.90
# 503      9.28
# 504     55.00
# 505     20.68
# 506     22.86
# 507     17.50
# 508     16.79
# 509     15.00
# 510     24.00
# 511     36.70
# 512     15.30
#
# [513 rows x 25 columns]

# %%
# Drop 27 rows corresponding to 27 missing values
# Missing values found in 'Household_size', 'Income_CAT', 'Edu_father', and 'Edu_mother'

df_cleaned = df.dropna()
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 486 entries, 0 to 512
# Data columns (total 25 columns):
# Reference_no              486 non-null int64
# Actual_age_C              486 non-null float64
# Sex                       486 non-null int64
# Weight                    486 non-null float64
# Height_meter              486 non-null float64
# BMI                       486 non-null float64
# BMI_for_age               486 non-null float64
# Physical_fitness_score    486 non-null float64
# PFS_CAT                   486 non-null int64
# Breakfast                 486 non-null int64
# Lunch                     486 non-null int64
# Dinner                    486 non-null int64
# PA_total_score            486 non-null float64
# PA_CAT                    486 non-null int64
# Sleep_weekdays            486 non-null float64
# Sleep_weekend             486 non-null float64
# Sleep_percent             486 non-null float64
# Global_sleep_CAT          486 non-null int64
# Household_size            486 non-null float64
# Income_CAT                486 non-null float64
# Edu_father                486 non-null float64
# Edu_mother                486 non-null float64
# Interference_score_ALL    486 non-null float64
# WM_total                  486 non-null int64
# CF_total                  486 non-null float64
# dtypes: float64(16), int64(9)
# memory usage: 98.7 KB

# %%
# Summary statistics

df_cleaned.describe()
# Out:
#        Reference_no  Actual_age_C         Sex      Weight  Height_meter  \
# count    486.000000    486.000000  486.000000  486.000000    486.000000
# mean     256.069959     14.075512    1.604938   51.867695      1.564756
# std      148.917535      1.322689    0.489368   14.870932      0.080929
# min        1.000000     12.106776    1.000000   24.200000      1.365000
# 25%      127.250000     12.985626    1.000000   41.600000      1.508125
# 50%      256.500000     13.655031    2.000000   48.800000      1.558500
# 75%      385.750000     15.482546    2.000000   58.950000      1.618625
# max      513.000000     16.970000    2.000000  117.500000      1.875000
#
#               BMI  BMI_for_age  Physical_fitness_score     PFS_CAT  \
# count  486.000000   486.000000              486.000000  486.000000
# mean    21.004273     0.221049               62.973417    2.267490
# std      5.089657     1.515608               12.155276    0.975183
# min     12.988233    -3.950000               19.543974    1.000000
# 25%     17.328972    -0.885000               55.813953    2.000000
# 50%     19.850710     0.235000               60.913706    2.000000
# 75%     23.462314     1.267500               69.114578    3.000000
# max     42.743375     4.160000              126.315789    5.000000
#
#         Breakfast     ...      Sleep_weekend  Sleep_percent  Global_sleep_CAT  \
# count  486.000000     ...         486.000000     486.000000        486.000000
# mean     4.213992     ...           8.771770      82.883973          0.724280
# std      2.392318     ...           2.006336      17.249667          0.447337
# min      0.000000     ...           2.500000      19.317450          0.000000
# 25%      2.000000     ...           7.500000      74.074074          0.000000
# 50%      4.000000     ...           9.000000      87.500000          1.000000
# 75%      7.000000     ...          10.000000      96.774194          1.000000
# max      7.000000     ...          14.000000     101.818182          1.000000
#
#        Household_size  Income_CAT  Edu_father  Edu_mother  \
# count      486.000000  486.000000  486.000000  486.000000
# mean         5.462963    1.888889    3.277778    3.277778
# std          1.614901    0.807184    0.577053    0.587674
# min          2.000000    1.000000    1.000000    1.000000
# 25%          4.000000    1.000000    3.000000    3.000000
# 50%          5.000000    2.000000    3.000000    3.000000
# 75%          6.000000    3.000000    4.000000    4.000000
# max         12.000000    3.000000    4.000000    4.000000
#
#        Interference_score_ALL    WM_total    CF_total
# count              486.000000  486.000000  486.000000
# mean                 1.340364   17.306584   27.630988
# std                  6.563426    3.762901   19.443671
# min                -20.792857   10.000000  -15.000000
# 25%                 -2.850857   15.000000   14.392500
# 50%                  0.946207   17.000000   23.000000
# 75%                  5.245677   19.000000   36.207500
# max                 27.471264   30.000000  136.620000
#
# [8 rows x 25 columns]

# %% [markdown]
# # Data Storytelling

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import pylab
# Out:
# /Users/springboard/miniconda3/envs/tutorial/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# # 1. Ask the following questions and look for the answers using code and plots.

# %% [markdown]
# <div class="span5 alert alert-success">
# <p>Can you count something interesting?</p>
# </div>

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 486 entries, 0 to 512
# Data columns (total 25 columns):
# Reference_no              486 non-null int64
# Actual_age_C              486 non-null float64
# Sex                       486 non-null int64
# Weight                    486 non-null float64
# Height_meter              486 non-null float64
# BMI                       486 non-null float64
# BMI_for_age               486 non-null float64
# Physical_fitness_score    486 non-null float64
# PFS_CAT                   486 non-null int64
# Breakfast                 486 non-null int64
# Lunch                     486 non-null int64
# Dinner                    486 non-null int64
# PA_total_score            486 non-null float64
# PA_CAT                    486 non-null int64
# Sleep_weekdays            486 non-null float64
# Sleep_weekend             486 non-null float64
# Sleep_percent             486 non-null float64
# Global_sleep_CAT          486 non-null int64
# Household_size            486 non-null float64
# Income_CAT                486 non-null float64
# Edu_father                486 non-null float64
# Edu_mother                486 non-null float64
# Interference_score_ALL    486 non-null float64
# WM_total                  486 non-null int64
# CF_total                  486 non-null float64
# dtypes: float64(16), int64(9)
# memory usage: 98.7 KB

# %%
# Spread of Ages

student_age = df['Actual_age_C']

age_12 = len(student_age[:133])
print('Age 12: ' + str(age_12))

age_13 = len(student_age[133:311])
print('Age 13: ' + str(age_13))

age_14 = len(student_age[311:328])
print('Age 14: ' + str(age_14))

age_15 = len(student_age[328:480])
print('Age 15: ' + str(age_15))

age_16 = len(student_age[480:514])
print('Age 16: ' + str(age_16))
# Out:
# Age 12: 133
# Age 13: 178
# Age 14: 17
# Age 15: 152
# Age 16: 33

# %%
# Number of males vs. females
# 1 - males; 2 - females

df_cleaned['Sex'].value_counts(dropna=False).sort_values()

print('Number of Males: ' + str(192))
print('Number of Females: ' + str(294))
# Out:
# Number of Males: 192
# Number of Females: 294

# %%
# PFS_CAT levels
# 1 - poor; 2 - low average; 3 - high average; 4 - good; 5 - excellent 

df_cleaned['PFS_CAT'].value_counts(dropna=False).sort_values()

print('Poor Physical Fitness Level: ' + str(104))
print('Low Average Physical Fitness Level: ' + str(210))
print('High Average Physical Fitness Level: ' + str(127))
print('Good Physical Fitness Level: ' + str(28))
print('Excellent Physical Fitness Level: ' + str(17))
# Out:
# Poor Physical Fitness Level: 104
# Low Average Physical Fitness Level: 210
# High Average Physical Fitness Level: 127
# Good Physical Fitness Level: 28
# Excellent Physical Fitness Level: 17

# %%
#PA_CAT levels
# 1 - low level; 2 - moderate levels; 3 - high levels 

df_cleaned['PA_CAT'].value_counts(dropna=False).sort_values()

print('Low Physical Activity Level: ' + str(191))
print('Moderate Physical Activity Level: ' + str(266))
print('High Physical Activity Level: ' + str(29))
# Out:
# Low Physical Activity Level: 191
# Moderate Physical Activity Level: 266
# High Physical Activity Level: 29

# %%
# Global_sleep_CAT levels
# 0 - poor sleep quality; 1 - good sleep quality

df_cleaned['Global_sleep_CAT'].value_counts(dropna=False).sort_values()

print('Poor Sleep Quality Levels: ' + str(134))
print('Good Sleep Quality Score: ' + str(352))
# Out:
# Poor Sleep Quality Levels: 134
# Good Sleep Quality Score: 352

# %% [markdown]
# <div class="span5 alert alert-success">
# <p>Can you find trends? Can you compare two related quantities? Can you make a bar plot or a histogram? Can you make a scatterplot?</p>
# </div>

# %% [markdown]
# ** *Box Plots* **

# %%
# Distribution of EF results
cols = ['Interference_score_ALL', 'WM_total', 'CF_total']
df_cleaned[cols].plot(kind='box', subplots=True)
plt.show()

# %% [markdown]
# **Categorial Variable #1 - Sex**

# %%
var_sex_1 = sns.boxplot(x='Sex', y='Interference_score_ALL', data=df_cleaned)
# Out:
# /Users/springboard/miniconda3/envs/tutorial/lib/python2.7/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
var_sex_2 = sns.boxplot(x='Sex', y='WM_total', data=df_cleaned)

# %%
var_sex_3 = sns.boxplot(x='Sex', y='CF_total', data=df_cleaned)

# %% [markdown]
# **Categorial Variable #2 - Physical Fitness Score (PFS_CAT)**

# %%
PFS_CAT1 = sns.boxplot(x='PFS_CAT', y='Interference_score_ALL', data=df_cleaned)

# %%
PFS_CAT2 = sns.boxplot(x='PFS_CAT', y='WM_total', data=df_cleaned)

# %%
PFS_CAT3 = sns.boxplot(x='PFS_CAT', y='CF_total', data=df_cleaned)

# %% [markdown]
# **Categorial Variable #3 - Physical Activity Level (PA_CAT)**

# %%
PA_CAT1 = sns.boxplot(x='PA_CAT', y='Interference_score_ALL', data=df_cleaned)

# %%
PA_CAT2 = sns.boxplot(x='PA_CAT', y='WM_total', data=df_cleaned)

# %%
PA_CAT3 = sns.boxplot(x='PFS_CAT', y='CF_total', data=df_cleaned)

# %% [markdown]
# **Categorial Variable #4 - Global Sleep Category**

# %%
Sleep_CAT1 = sns.boxplot(x='Global_sleep_CAT', y='Interference_score_ALL', data=df_cleaned)

# %%
Sleep_CAT2 = sns.boxplot(x='Global_sleep_CAT', y='WM_total', data=df_cleaned)

# %%
Sleep_CAT3 = sns.boxplot(x='Global_sleep_CAT', y='CF_total', data=df_cleaned)

# %% [markdown]
# **Categorial Variable #5 - Household Size**

# %%
household_1 = sns.boxplot(x='Household_size', y='Interference_score_ALL', data=df_cleaned)

# %%
household_2 = sns.boxplot(x='Household_size', y='WM_total', data=df_cleaned)

# %%
household_3 = sns.boxplot(x='Household_size', y='CF_total', data=df_cleaned)

# %% [markdown]
# **Categorial Variable #6 - Income Category**

# %%
income_1 = sns.boxplot(x='Income_CAT', y='Interference_score_ALL', data=df_cleaned)

# %%
income_2 = sns.boxplot(x='Income_CAT', y='WM_total', data=df_cleaned)

# %%
income_3 = sns.boxplot(x='Income_CAT', y='CF_total', data=df_cleaned)

# %% [markdown]
# <div class="span5 alert alert-success">
# <p>...</p>
# </div>

# %% [markdown]
# **Continuous Variable #1 - Age**

# %%
# Age vs. Interference

df_cleaned.plot(kind='scatter', x='Actual_age_C', y='Interference_score_ALL')
plt.xlabel('Age')
plt.ylabel('Interference')
plt.show()

# Age vs. Working Memory

df_cleaned.plot(kind='scatter', x='Actual_age_C', y='WM_total')
plt.xlabel('Age')
plt.ylabel('Working Memory')
plt.show()

# Age vs. Cognitive Flexibility

df_cleaned.plot(kind='scatter', x='Actual_age_C', y='CF_total')
plt.xlabel('Age')
plt.ylabel('Cognitive Flexibility')
plt.show()

# %% [markdown]
# **Continuous Variable #2 - BMI**

# %%
# BMI vs. Interference

df_cleaned.plot(kind='scatter', x='BMI', y='Interference_score_ALL')
plt.xlabel('BMI')
plt.ylabel('Interference')
plt.show()

# BMI vs. Working Memory

df_cleaned.plot(kind='scatter', x='BMI', y='WM_total')
plt.xlabel('BMI')
plt.ylabel('Working Memory')
plt.show()

# BMI vs. Cognitive Flexibility

df_cleaned.plot(kind='scatter', x='BMI', y='CF_total')
plt.xlabel('BMI')
plt.ylabel('Cognitive Flexibility')
plt.show()

# %% [markdown]
# **Continuous Variable #3 - BMI for Age**

# %%
# BMI for Age vs. Interference

df_cleaned.plot(kind='scatter', x='BMI_for_age', y='Interference_score_ALL')
plt.xlabel('BMI for Age')
plt.ylabel('Interference')
plt.show()

# BMI for Age vs. Working Memory

df_cleaned.plot(kind='scatter', x='BMI_for_age', y='WM_total')
plt.xlabel('BMI for Age')
plt.ylabel('Working Memory')
plt.show()

# BMI for Age vs. Cognitive Flexibility

df_cleaned.plot(kind='scatter', x='BMI_for_age', y='CF_total')
plt.xlabel('BMI for Age')
plt.ylabel('Cognitive Flexibility')
plt.show()

# %% [markdown]
# **Continuous Variable #4 - Sleep Percent**

# %%
# Sleep Percent vs. Interference

df_cleaned.plot(kind='scatter', x='Sleep_percent', y='Interference_score_ALL')
plt.xlabel('Sleep Percent')
plt.ylabel('Interference')
plt.show()

# Sleep Percent vs. Working Memory

df_cleaned.plot(kind='scatter', x='Sleep_percent', y='WM_total')
plt.xlabel('Sleep Percent')
plt.ylabel('Working Memory')
plt.show()

# Sleep Percent vs. Cognitive Flexibility

df_cleaned.plot(kind='scatter', x='Sleep_percent', y='CF_total')
plt.xlabel('Sleep Percent')
plt.ylabel('Cognitive Flexibility')
plt.show()

# %% [markdown]
# <div class="span5 alert alert-success">
# <p>...</p>
# </div>

# %%
# Correlation Matrix
sns.heatmap(df_cleaned.corr())

# %%
df_cleaned.corr()
# Out:
#                         Reference_no  Actual_age_C       Sex    Weight  \
# Reference_no                1.000000      0.975941  0.148239  0.321431
# Actual_age_C                0.975941      1.000000  0.137328  0.326611
# Sex                         0.148239      0.137328  1.000000 -0.089588
# Weight                      0.321431      0.326611 -0.089588  1.000000
# Height_meter                0.428171      0.440337 -0.266859  0.556945
# BMI                         0.197121      0.198948  0.018108  0.933468
# BMI_for_age                -0.006866     -0.005507 -0.060265  0.848731
# Physical_fitness_score      0.038693      0.046706 -0.412361 -0.206079
# PFS_CAT                     0.066218      0.074000 -0.395942 -0.138880
# Breakfast                  -0.088661     -0.088767 -0.100235 -0.084497
# Lunch                       0.098138      0.093638  0.090462 -0.059312
# Dinner                     -0.016997     -0.034442  0.033411 -0.085494
# PA_total_score             -0.211648     -0.224399 -0.203702 -0.067638
# PA_CAT                     -0.200753     -0.210653 -0.187246 -0.033471
# Sleep_weekdays             -0.395110     -0.424595 -0.041686 -0.219134
# Sleep_weekend              -0.097799     -0.089508  0.052898 -0.073185
# Sleep_percent               0.021000      0.002914  0.050042 -0.047061
# Global_sleep_CAT            0.097075      0.120973  0.075931  0.122822
# Household_size              0.007110      0.001018  0.033627 -0.034320
# Income_CAT                 -0.119251     -0.132843 -0.116575  0.081841
# Edu_father                 -0.146180     -0.151824 -0.136293  0.022552
# Edu_mother                 -0.171999     -0.177390 -0.105152  0.027713
# Interference_score_ALL      0.024539      0.028833 -0.027108 -0.051976
# WM_total                    0.058661      0.054462  0.032319 -0.028570
# CF_total                   -0.160566     -0.146156 -0.115450 -0.002099
#
#                         Height_meter       BMI  BMI_for_age  \
# Reference_no                0.428171  0.197121    -0.006866
# Actual_age_C                0.440337  0.198948    -0.005507
# Sex                        -0.266859  0.018108    -0.060265
# Weight                      0.556945  0.933468     0.848731
# Height_meter                1.000000  0.235721     0.179160
# BMI                         0.235721  1.000000     0.929111
# BMI_for_age                 0.179160  0.929111     1.000000
# Physical_fitness_score      0.087528 -0.287882    -0.250513
# PFS_CAT                     0.120497 -0.225078    -0.203712
# Breakfast                   0.013784 -0.110866    -0.098423
# Lunch                       0.003588 -0.073842    -0.095414
# Dinner                      0.001146 -0.105277    -0.113161
# PA_total_score             -0.035341 -0.071158    -0.016107
# PA_CAT                      0.011453 -0.051761    -0.003093
# Sleep_weekdays             -0.180866 -0.187230    -0.123685
# Sleep_weekend               0.022278 -0.092360    -0.089806
# Sleep_percent              -0.084594 -0.023744    -0.017151
# Global_sleep_CAT            0.085762  0.112116     0.081657
# Household_size             -0.073505 -0.007011     0.011923
# Income_CAT                  0.082501  0.060555     0.101454
# Edu_father                 -0.008216  0.026843     0.058321
# Edu_mother                 -0.008002  0.031946     0.072476
# Interference_score_ALL      0.057463 -0.084408    -0.089399
# WM_total                    0.071683 -0.070478    -0.094135
# CF_total                   -0.031656  0.007380     0.038542
#
#                         Physical_fitness_score   PFS_CAT  Breakfast    ...     \
# Reference_no                          0.038693  0.066218  -0.088661    ...
# Actual_age_C                          0.046706  0.074000  -0.088767    ...
# Sex                                  -0.412361 -0.395942  -0.100235    ...
# Weight                               -0.206079 -0.138880  -0.084497    ...
# Height_meter                          0.087528  0.120497   0.013784    ...
# BMI                                  -0.287882 -0.225078  -0.110866    ...
# BMI_for_age                          -0.250513 -0.203712  -0.098423    ...
# Physical_fitness_score                1.000000  0.922814   0.040718    ...
# PFS_CAT                               0.922814  1.000000   0.034628    ...
# Breakfast                             0.040718  0.034628   1.000000    ...
# Lunch                                -0.032503 -0.015392   0.202519    ...
# Dinner                               -0.005314  0.022660   0.257905    ...
# PA_total_score                        0.220417  0.237026   0.132738    ...
# PA_CAT                                0.198465  0.218045   0.064329    ...
# Sleep_weekdays                       -0.057906 -0.077115   0.057081    ...
# Sleep_weekend                        -0.070137 -0.081577   0.038986    ...
# Sleep_percent                        -0.018324 -0.019933   0.049262    ...
# Global_sleep_CAT                     -0.074415 -0.057457  -0.195219    ...
# Household_size                        0.030341  0.056056  -0.052381    ...
# Income_CAT                            0.015444  0.006403   0.094555    ...
# Edu_father                            0.047166  0.021577   0.058415    ...
# Edu_mother                            0.073333  0.042774   0.048560    ...
# Interference_score_ALL                0.022731 -0.010639   0.017499    ...
# WM_total                             -0.009480 -0.012281   0.121877    ...
# CF_total                              0.069322  0.035221  -0.011434    ...
#
#                         Sleep_weekend  Sleep_percent  Global_sleep_CAT  \
# Reference_no                -0.097799       0.021000          0.097075
# Actual_age_C                -0.089508       0.002914          0.120973
# Sex                          0.052898       0.050042          0.075931
# Weight                      -0.073185      -0.047061          0.122822
# Height_meter                 0.022278      -0.084594          0.085762
# BMI                         -0.092360      -0.023744          0.112116
# BMI_for_age                 -0.089806      -0.017151          0.081657
# Physical_fitness_score      -0.070137      -0.018324         -0.074415
# PFS_CAT                     -0.081577      -0.019933         -0.057457
# Breakfast                    0.038986       0.049262         -0.195219
# Lunch                        0.002326       0.105181         -0.100056
# Dinner                       0.071743       0.078793         -0.116455
# PA_total_score              -0.025449       0.014768         -0.073629
# PA_CAT                      -0.030272      -0.006499         -0.028888
# Sleep_weekdays               0.405406      -0.094892         -0.152931
# Sleep_weekend                1.000000      -0.289612         -0.102421
# Sleep_percent               -0.289612       1.000000         -0.342935
# Global_sleep_CAT            -0.102421      -0.342935          1.000000
# Household_size              -0.057444      -0.026391          0.034356
# Income_CAT                  -0.125603      -0.002026         -0.027917
# Edu_father                  -0.169931       0.014268          0.033725
# Edu_mother                  -0.095338      -0.019214         -0.006100
# Interference_score_ALL      -0.074683       0.110117         -0.034057
# WM_total                     0.029596       0.091856         -0.151787
# CF_total                     0.010588      -0.057061          0.028976
#
#                         Household_size  Income_CAT  Edu_father  Edu_mother  \
# Reference_no                  0.007110   -0.119251   -0.146180   -0.171999
# Actual_age_C                  0.001018   -0.132843   -0.151824   -0.177390
# Sex                           0.033627   -0.116575   -0.136293   -0.105152
# Weight                       -0.034320    0.081841    0.022552    0.027713
# Height_meter                 -0.073505    0.082501   -0.008216   -0.008002
# BMI                          -0.007011    0.060555    0.026843    0.031946
# BMI_for_age                   0.011923    0.101454    0.058321    0.072476
# Physical_fitness_score        0.030341    0.015444    0.047166    0.073333
# PFS_CAT                       0.056056    0.006403    0.021577    0.042774
# Breakfast                    -0.052381    0.094555    0.058415    0.048560
# Lunch                        -0.160198    0.045873    0.080358    0.021326
# Dinner                       -0.115609    0.073199    0.050138    0.049232
# PA_total_score                0.061016    0.024000    0.113963    0.075074
# PA_CAT                        0.048012   -0.004366    0.079397    0.059971
# Sleep_weekdays               -0.028395   -0.190613   -0.177312   -0.155680
# Sleep_weekend                -0.057444   -0.125603   -0.169931   -0.095338
# Sleep_percent                -0.026391   -0.002026    0.014268   -0.019214
# Global_sleep_CAT              0.034356   -0.027917    0.033725   -0.006100
# Household_size                1.000000    0.003164   -0.038720   -0.027157
# Income_CAT                    0.003164    1.000000    0.535618    0.517245
# Edu_father                   -0.038720    0.535618    1.000000    0.592804
# Edu_mother                   -0.027157    0.517245    0.592804    1.000000
# Interference_score_ALL       -0.041952    0.090687   -0.015432    0.026860
# WM_total                     -0.098053    0.180268    0.129720    0.078891
# CF_total                      0.082525   -0.057487   -0.018747   -0.009755
#
#                         Interference_score_ALL  WM_total  CF_total
# Reference_no                          0.024539  0.058661 -0.160566
# Actual_age_C                          0.028833  0.054462 -0.146156
# Sex                                  -0.027108  0.032319 -0.115450
# Weight                               -0.051976 -0.028570 -0.002099
# Height_meter                          0.057463  0.071683 -0.031656
# BMI                                  -0.084408 -0.070478  0.007380
# BMI_for_age                          -0.089399 -0.094135  0.038542
# Physical_fitness_score                0.022731 -0.009480  0.069322
# PFS_CAT                              -0.010639 -0.012281  0.035221
# Breakfast                             0.017499  0.121877 -0.011434
# Lunch                                -0.036618  0.146124 -0.115691
# Dinner                                0.056160  0.162071 -0.096705
# PA_total_score                       -0.055476  0.043035  0.071256
# PA_CAT                               -0.047689  0.011864  0.081307
# Sleep_weekdays                       -0.031362 -0.061481  0.111590
# Sleep_weekend                        -0.074683  0.029596  0.010588
# Sleep_percent                         0.110117  0.091856 -0.057061
# Global_sleep_CAT                     -0.034057 -0.151787  0.028976
# Household_size                       -0.041952 -0.098053  0.082525
# Income_CAT                            0.090687  0.180268 -0.057487
# Edu_father                           -0.015432  0.129720 -0.018747
# Edu_mother                            0.026860  0.078891 -0.009755
# Interference_score_ALL                1.000000  0.098574 -0.165008
# WM_total                              0.098574  1.000000 -0.225948
# CF_total                             -0.165008 -0.225948  1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# # 2. Looking at the plots, what are some insights you can make? Do you see any correlations? Is there a hypothesis you’d like to investigate further? What other questions do the insights lead you to ask?

# %% [markdown]
# While there is a relatively even spread of 12, 13, and 15 year olds, only 0.033% of the data set is comprised of 14 year old students and 0.064% are 16 year olds. It’s possible that the 14 and 16 year-olds can be considered outliers. There are also 100 more female students included in the dataset than males.
#
# The interference distribution is very similar for males and females. There is slightly more variation in the distribution for working memory, while it's clear that there is a significant difference between males and females when it comes to cognitive flexibility.
#
# The EF distributions are similar for all physical fitness score categories, though the differences in physical activity distributions suggests there are differences between groups.
#
# The working memory median is the same for both sleep category groups, but there is a large difference in their distributions. There is no variation for cognitive flexibility.
#
# Household size shows large discrepancies for all executive functions. Income category shows a stable distribution for interference and cognitive flexibility, but displays a strong discrepancy when it comes to working memory.
#
# The scatter plots don't show any strong correlations, bar a slightly negative correlation between BMI and interference.

# %% [markdown]
# # 3. Now that you’ve asked questions, hopefully you’ve found some interesting insights. Is there a narrative or a way of presenting the insights using text and plots that tells a compelling story? What are some other trends/relationships you think will make the story more complete?

# %% [markdown]
# Executive function is defined by interference, working memory, and cognitive flexibility. Based on the analysis above however, it seems as if working memory shows the greatest variability between different lifestyle factors, followed closely by cognitive flexibility.
#
# Working memory holds important information temporarily - information which is not stored in long-term memory. Efficient working memory allows an individual to reason and make important decisions. As such, it would be important to look at working memory as a whole, and determine which lifestyle factors affect its function the most in an effort to determine how the process can be improved.
